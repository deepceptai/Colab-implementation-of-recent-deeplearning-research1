# %%
# !git clone https://github.com/hzwer/LearningToPaint.git
# Out:
# Cloning into 'LearningToPaint'...
# remote: Enumerating objects: 476, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 476 (delta 0), reused 1 (delta 0), pack-reused 473
# Receiving objects: 100% (476/476), 18.67 MiB | 19.27 MiB/s, done.
# Resolving deltas: 100% (259/259), done.

# %%
cd LearningToPaint/
# Out:
# /content/LearningToPaint/LearningToPaint

# %% [markdown]
# Testing

# %%
# !wget "https://drive.google.com/uc?export=download&id=1-7dVdjCIZIxh8hHJnGTK-RA1-jL1tor4" -O renderer.pkl
# Out:
# --2023-12-08 05:46:48--  https://drive.google.com/uc?export=download&id=1-7dVdjCIZIxh8hHJnGTK-RA1-jL1tor4
# Resolving drive.google.com (drive.google.com)... 142.251.8.102, 142.251.8.101, 142.251.8.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.8.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0o-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jr7sm8gjs1de6u3mrgb2gahg9f2cd10q/1702014375000/10102393604162075786/*/1-7dVdjCIZIxh8hHJnGTK-RA1-jL1tor4?e=download&uuid=4a24a43a-aadb-4553-8250-46413c2a4885 [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-08 05:46:51--  https://doc-0o-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jr7sm8gjs1de6u3mrgb2gahg9f2cd10q/1702014375000/10102393604162075786/*/1-7dVdjCIZIxh8hHJnGTK-RA1-jL1tor4?e=download&uuid=4a24a43a-aadb-4553-8250-46413c2a4885
# Resolving doc-0o-58-docs.googleusercontent.com (doc-0o-58-docs.googleusercontent.com)... 74.125.203.132, 2404:6800:4008:c03::84
# Connecting to doc-0o-58-docs.googleusercontent.com (doc-0o-58-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44165821 (42M) [application/octet-stream]
# Saving to: ‘renderer.pkl’
#
# renderer.pkl        100%[===================>]  42.12M   169MB/s    in 0.2s
#
# 2023-12-08 05:46:51 (169 MB/s) - ‘renderer.pkl’ saved [44165821/44165821]

# %%
# !wget "https://drive.google.com/uc?export=download&id=1a3vpKgjCVXHON4P7wodqhCgCMPgg1KeR" -O actor.pkl
# Out:
# --2023-12-08 05:46:58--  https://drive.google.com/uc?export=download&id=1a3vpKgjCVXHON4P7wodqhCgCMPgg1KeR
# Resolving drive.google.com (drive.google.com)... 142.251.8.102, 142.251.8.101, 142.251.8.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.8.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/n2r7s6entmkt22kan07lkt1hmcleqlkv/1702014375000/10102393604162075786/*/1a3vpKgjCVXHON4P7wodqhCgCMPgg1KeR?e=download&uuid=debd2d47-5d7f-4edd-9a4d-b32dc5170d5f [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-08 05:47:00--  https://doc-0c-58-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/n2r7s6entmkt22kan07lkt1hmcleqlkv/1702014375000/10102393604162075786/*/1a3vpKgjCVXHON4P7wodqhCgCMPgg1KeR?e=download&uuid=debd2d47-5d7f-4edd-9a4d-b32dc5170d5f
# Resolving doc-0c-58-docs.googleusercontent.com (doc-0c-58-docs.googleusercontent.com)... 74.125.203.132, 2404:6800:4008:c03::84
# Connecting to doc-0c-58-docs.googleusercontent.com (doc-0c-58-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44898539 (43M) [application/octet-stream]
# Saving to: ‘actor.pkl’
#
# actor.pkl           100%[===================>]  42.82M   177MB/s    in 0.2s
#
# 2023-12-08 05:47:01 (177 MB/s) - ‘actor.pkl’ saved [44898539/44898539]

# %%
# !wget -U NoSuchBrowser/1.0 -O image/test.png https://raw.githubusercontent.com/hzwer/LearningToPaint/master/image/lisa.png
# Out:
# --2023-12-08 05:47:08--  https://raw.githubusercontent.com/hzwer/LearningToPaint/master/image/lisa.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42420 (41K) [image/png]
# Saving to: ‘image/test.png’
#
# image/test.png      100%[===================>]  41.43K  --.-KB/s    in 0.04s
#
# 2023-12-08 05:47:08 (1000 KB/s) - ‘image/test.png’ saved [42420/42420]

# %%
# !python3 baseline/test.py --max_step=80 --actor=actor.pkl --renderer=renderer.pkl --img=image/test.png --divide=5
# Out:
# canvas step 0, L2Loss = 0.023610137403011322
# canvas step 1, L2Loss = 0.015413206070661545
# canvas step 2, L2Loss = 0.011502303183078766
# canvas step 3, L2Loss = 0.009824689477682114
# canvas step 4, L2Loss = 0.008571169339120388
# canvas step 5, L2Loss = 0.007355470675975084
# canvas step 6, L2Loss = 0.006380216684192419
# canvas step 7, L2Loss = 0.005760638043284416
# canvas step 8, L2Loss = 0.005315376445651054
# canvas step 9, L2Loss = 0.004998145159333944
# canvas step 10, L2Loss = 0.004723197314888239
# canvas step 11, L2Loss = 0.004502768162637949
# canvas step 12, L2Loss = 0.004276350140571594
# canvas step 13, L2Loss = 0.004127503838390112
# canvas step 14, L2Loss = 0.003954217303544283
# canvas step 15, L2Loss = 0.0038526856806129217
# canvas step 16, L2Loss = 0.00371532398276031
# canvas step 17, L2Loss = 0.003627510042861104
# canvas step 18, L2Loss = 0.0035386614035815
# canvas step 19, L2Loss = 0.0034513857681304216
# canvas step 20, L2Loss = 0.0033618195448070765
# canvas step 21, L2Loss = 0.003285651793703437
# canvas step 22, L2Loss = 0.00322786346077919
# canvas step 23, L2Loss = 0.003185648238286376
# canvas step 24, L2Loss = 0.0031280063558369875
# canvas step 25, L2Loss = 0.0030944468453526497
# canvas step 26, L2Loss = 0.003059541108086705
# canvas step 27, L2Loss = 0.0030167854856699705
# canvas step 28, L2Loss = 0.003004813566803932
# canvas step 29, L2Loss = 0.002948229433968663
# canvas step 30, L2Loss = 0.0029270704835653305
# canvas step 31, L2Loss = 0.002893283264711499
# canvas step 32, L2Loss = 0.0028582278173416853
# canvas step 33, L2Loss = 0.0028328057378530502
# canvas step 34, L2Loss = 0.002809579484164715
# canvas step 35, L2Loss = 0.002770649269223213
# canvas step 36, L2Loss = 0.0027464258018881083
# canvas step 37, L2Loss = 0.0027224032673984766
# canvas step 38, L2Loss = 0.002707442967221141
# canvas step 39, L2Loss = 0.002692570211365819
# divided canvas step 0, L2Loss = 0.0014894065679982305
# divided canvas step 1, L2Loss = 0.001188380760140717
# divided canvas step 2, L2Loss = 0.00103595363907516
# divided canvas step 3, L2Loss = 0.0009114869171753526
# divided canvas step 4, L2Loss = 0.0008365378598682582
# divided canvas step 5, L2Loss = 0.0007733680540695786
# divided canvas step 6, L2Loss = 0.0007283115410245955
# divided canvas step 7, L2Loss = 0.0006806713063269854
# divided canvas step 8, L2Loss = 0.0006432581576518714
# divided canvas step 9, L2Loss = 0.0006102971965447068
# divided canvas step 10, L2Loss = 0.0005811522132717073
# divided canvas step 11, L2Loss = 0.0005582798621617258
# divided canvas step 12, L2Loss = 0.0005379386711865664
# divided canvas step 13, L2Loss = 0.0005167889758013189
# divided canvas step 14, L2Loss = 0.0004980089724995196
# divided canvas step 15, L2Loss = 0.00048468937166035175
# divided canvas step 16, L2Loss = 0.0004728481580968946
# divided canvas step 17, L2Loss = 0.00046188905253075063
# divided canvas step 18, L2Loss = 0.00045168455108068883
# divided canvas step 19, L2Loss = 0.00044259894639253616
# divided canvas step 20, L2Loss = 0.00043516105506569147
# divided canvas step 21, L2Loss = 0.0004286702023819089
# divided canvas step 22, L2Loss = 0.00042190044769085944
# divided canvas step 23, L2Loss = 0.0004155565984547138
# divided canvas step 24, L2Loss = 0.0004102188104297966
# divided canvas step 25, L2Loss = 0.00040565148810856044
# divided canvas step 26, L2Loss = 0.000401826313463971
# divided canvas step 27, L2Loss = 0.0003975462168455124
# divided canvas step 28, L2Loss = 0.0003921884926967323
# divided canvas step 29, L2Loss = 0.00038861000211909413
# divided canvas step 30, L2Loss = 0.00038340521859936416
# divided canvas step 31, L2Loss = 0.0003790810878854245
# divided canvas step 32, L2Loss = 0.0003752264892682433
# divided canvas step 33, L2Loss = 0.0003711207245942205
# divided canvas step 34, L2Loss = 0.00036623398773372173
# divided canvas step 35, L2Loss = 0.000362906779628247
# divided canvas step 36, L2Loss = 0.0003588086401578039
# divided canvas step 37, L2Loss = 0.00035510293673723936
# divided canvas step 38, L2Loss = 0.0003513280244078487
# divided canvas step 39, L2Loss = 0.00034676448558457196

# %%
# !ffmpeg -r 30 -f image2 -i output/generated%d.png -s 512x512 -c:v libx264 -pix_fmt yuv420p video.mp4 -q:v 0 -q:a 0
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Trailing option(s) found in the command: may be ignored.
# Input #0, image2, from 'output/generated%d.png':
#   Duration: 00:00:13.33, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 128x128, 30 fps, 30 tbr, 30 tbn, 30 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x579c79c7cc00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x579c79c7cc00] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x579c79c7cc00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  400 fps= 74 q=-1.0 Lsize=     169kB time=00:00:13.23 bitrate= 104.3kbits/s speed=2.46x
# video:163kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.368054%
# [libx264 @ 0x579c79c7cc00] frame I:2     Avg QP:18.24  size: 11687
# [libx264 @ 0x579c79c7cc00] frame P:105   Avg QP:18.49  size:  1151
# [libx264 @ 0x579c79c7cc00] frame B:293   Avg QP:27.15  size:    75
# [libx264 @ 0x579c79c7cc00] consecutive B-frames:  1.2%  2.5%  2.2% 94.0%
# [libx264 @ 0x579c79c7cc00] mb I  I16..4:  5.8% 90.5%  3.8%
# [libx264 @ 0x579c79c7cc00] mb P  I16..4:  0.5%  3.3%  0.2%  P16..4:  9.4%  3.0%  1.6%  0.0%  0.0%    skip:81.9%
# [libx264 @ 0x579c79c7cc00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  6.1%  0.1%  0.0%  direct: 0.0%  skip:93.8%  L0:42.2% L1:57.6% BI: 0.1%
# [libx264 @ 0x579c79c7cc00] 8x8 transform intra:84.2% inter:88.0%
# [libx264 @ 0x579c79c7cc00] coded y,uvDC,uvAC intra: 54.7% 69.1% 45.7% inter: 1.2% 2.1% 0.1%
# [libx264 @ 0x579c79c7cc00] i16 v,h,dc,p: 22% 29%  7% 42%
# [libx264 @ 0x579c79c7cc00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 18% 12%  5%  5%  6%  5%  7%  6%
# [libx264 @ 0x579c79c7cc00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 22% 11%  5% 10%  7%  6%  4%  2%
# [libx264 @ 0x579c79c7cc00] i8c dc,h,v,p: 52% 18% 21%  9%
# [libx264 @ 0x579c79c7cc00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x579c79c7cc00] ref P L0: 75.6%  7.2% 15.2%  2.0%
# [libx264 @ 0x579c79c7cc00] ref B L0: 86.3% 13.3%  0.4%
# [libx264 @ 0x579c79c7cc00] ref B L1: 95.7%  4.3%
# [libx264 @ 0x579c79c7cc00] kb/s:99.76

# %%
from IPython.display import display, Image
import moviepy.editor as mpy
display(mpy.ipython_display('video.mp4', height=300, max_duration=100.))
display(Image('output/generated399.png'))
# Out:
# <div align=middle><video height='300' max_duration='100.0'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# Training

# %%
# !mkdir data

# %%
# %cd data
# Out:
# /content/LearningToPaint/LearningToPaint/data

# %%
# !gdown https://drive.google.com/open?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:35: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/open?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
# To: /content/LearningToPaint/LearningToPaint/data/open?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
# 84.7kB [00:00, 12.5MB/s]

# %%
# !unzip img_align_celeba.zip
# Out:
# unzip:  cannot find or open img_align_celeba.zip, img_align_celeba.zip.zip or img_align_celeba.zip.ZIP.

# %%
# !rm img_align_celeba.zip
# Out:
# rm: cannot remove 'img_align_celeba.zip': No such file or directory

# %%
cd ..
# Out:
# /content/LearningToPaint/LearningToPaint

# %%
# !python3 baseline/train_renderer.py
# Out:
# /content/LearningToPaint/LearningToPaint/baseline/train_renderer.py:49: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   train_batch = torch.tensor(train_batch).float()
# 0 0.0005010158638469875
# Traceback (most recent call last):
#   File "/content/LearningToPaint/LearningToPaint/baseline/train_renderer.py", line 78, in <module>
#     writer.add_image("train/gen{}.png".format(i), G, step)
#   File "/content/LearningToPaint/LearningToPaint/baseline/utils/tensorboard.py", line 17, in add_image
#     elif type(img) == PIL.Image.Image:
# AttributeError: module 'PIL' has no attribute 'Image'

# %%
# !pip install tensorboardX
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (2.6.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)

# %%
# %%writefile baseline/env.py
import sys
import json
import torch
import numpy as np
import argparse
import torchvision.transforms as transforms
import cv2
from DRL.ddpg import decode
from utils.util import *
from PIL import Image
from torchvision import transforms, utils
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

aug = transforms.Compose(
            [transforms.ToPILImage(),
             transforms.RandomHorizontalFlip(),
             ])

width = 128
convas_area = width * width

img_train = []
img_test = []
train_num = 0
test_num = 0

class Paint:
    def __init__(self, batch_size, max_step):
        self.batch_size = batch_size
        self.max_step = max_step
        self.action_space = (13)
        self.observation_space = (self.batch_size, width, width, 7)
        self.test = False

    def load_data(self):
        # CelebA
        global train_num, test_num
        for i in range(200000):
            img_id = '%06d' % (i + 1)
            try:
                img = cv2.imread('./data/img_align_celeba/' + img_id + '.jpg', cv2.IMREAD_UNCHANGED)
                img = cv2.resize(img, (width, width))
                if i > 2000:
                    train_num += 1
                    img_train.append(img)
                else:
                    test_num += 1
                    img_test.append(img)
            finally:
                if (i + 1) % 10000 == 0:
                    print('loaded {} images'.format(i + 1))
        print('finish loading data, {} training images, {} testing images'.format(str(train_num), str(test_num)))

    def pre_data(self, id, test):
        if test:
            img = img_test[id]
        else:
            img = img_train[id]
        if not test:
            img = aug(img)
        img = np.asarray(img)
        return np.transpose(img, (2, 0, 1))

    def reset(self, test=False, begin_num=False):
        self.test = test
        self.imgid = [0] * self.batch_size
        self.gt = torch.zeros([self.batch_size, 3, width, width], dtype=torch.uint8).to(device)
        for i in range(self.batch_size):
            if test:
                id = (i + begin_num)  % test_num
            else:
                id = np.random.randint(train_num)
            self.imgid[i] = id
            self.gt[i] = torch.tensor(self.pre_data(id, test))
        self.tot_reward = ((self.gt.float() / 255) ** 2).mean(1).mean(1).mean(1)
        self.stepnum = 0
        self.canvas = torch.zeros([self.batch_size, 3, width, width], dtype=torch.uint8).to(device)
        self.lastdis = self.ini_dis = self.cal_dis()
        return self.observation()

    def observation(self):
        # canvas B * 3 * width * width
        # gt B * 3 * width * width
        # T B * 1 * width * width
        ob = []
        T = torch.ones([self.batch_size, 1, width, width], dtype=torch.uint8) * self.stepnum
        return torch.cat((self.canvas, self.gt, T.to(device)), 1) # canvas, img, T

    def cal_trans(self, s, t):
        return (s.transpose(0, 3) * t).transpose(0, 3)

    def step(self, action):
        self.canvas = (decode(action, self.canvas.float() / 255) * 255).byte()
        self.stepnum += 1
        ob = self.observation()
        done = (self.stepnum == self.max_step)
        reward = self.cal_reward() # np.array([0.] * self.batch_size)
        return ob.detach(), reward, np.array([done] * self.batch_size), None

    def cal_dis(self):
        return (((self.canvas.float() - self.gt.float()) / 255) ** 2).mean(1).mean(1).mean(1)

    def cal_reward(self):
        dis = self.cal_dis()
        reward = (self.lastdis - dis) / (self.ini_dis + 1e-8)
        self.lastdis = dis
        return to_numpy(reward)
# Out:
# Overwriting baseline/env.py

# %%
# !python3 baseline/train.py --max_step=200 --debug --batch_size=96
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# [ WARN:0@6.956] global loadsave.cpp:248 findDecoder imread_('./data/img_align_celeba/000001.jpg'): can't open/read file: check file path/integrity
# Traceback (most recent call last):
#   File "/content/LearningToPaint/LearningToPaint/baseline/train.py", line 108, in <module>
#     fenv = fastenv(args.max_step, args.env_batch, writer)
#   File "/content/LearningToPaint/LearningToPaint/baseline/DRL/multi.py", line 16, in __init__
#     self.env.load_data()
#   File "/content/LearningToPaint/LearningToPaint/baseline/env.py", line 42, in load_data
#     img = cv2.resize(img, (width, width))
# cv2.error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
